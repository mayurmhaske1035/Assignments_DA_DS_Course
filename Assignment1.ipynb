# %% [markdown]
# TYPE CASTING

# %%
Str ="hello"
number_int = 10
number_float = 10.56		    
type(Str)
# Out:
# str

# %%
type(number_int)
# Out:
# int

# %%
type(number_float)
# Out:
# float

# %%
number = int(number_float)

# %%
number
# Out:
# 10

# %%
str_number = str(number)
str_float_number = str(number_float)

# %%
str_float_number
# Out:
# '10.56'

# %%
str_number
# Out:
# '10'

# %% [markdown]
# OPRATORS

# %%
# Assignment and Equal to Equal

# %%
number = 10
number2 = 20

# %%
number == number2
# Out:
# False

# %%
number == 10
# Out:
# True

# %%
#MODULES

# %%
number % 10
# Out:
# 0

# %%
number % number2
# Out:
# 10

# %%
#MULLTIPLICATIN

# %%
print("welcome"*3)
# Out:
# welcomewelcomewelcome

# %%
#CONCATINATION

# %%
str1 = 'Mayur' 
str2 = 'Mhaske'
print(f"I AM " + str1 +" "+ str2)
# Out:
# I AM Mayur Mhaske
