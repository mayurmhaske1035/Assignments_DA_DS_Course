# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[1:5]
# Out:
# [20, 30, 40, 50]

# %%
l[:4:1]
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# How do you get every second element (e.g., [10, 30, 50, 70])?

# %%
l1 = [10, 30, 50, 70,45,6,778,888]

# %%
l1[::2]
# Out:
# [10, 50]

# %%
l1[-3:]
# Out:
# [30, 50, 70]

# %%
l1[-4::-1]
# Out:
# [10]

# %%
l1[6::-2]
# Out:
# [778, 45, 50, 10]

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2:]
# Out:
# [[100, 200, [300, 400]], 5]

# %%
nested[2:3:2]
# Out:
# [[100, 200, [300, 400]]]

# %%
nested.index(5)
# Out:
# 3

# %%
nested.index([100, 200, [300, 400]])
# Out:
# 2

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
data[1][:2]
# Out:
# [4, 5]

# %%
data[1][::-1]
# Out:
# [6, 5, 4]

# %%
data[-1][-1]
# Out:
# 9

# %%
data[-2][-3]
# Out:
# 4

# %% [markdown]
# Write code to reverse only the middle three elements of a 5-element list.

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
l[-2:-7:-1]
# Out:
# [70, 60, 50, 40, 30]

# %% [markdown]
# Create a nested list where the first element is a string, and
# the second element is a slice of [1, 2, 3, 4, 5].

# %%
l1 = [ 'string', [1,2,3,4,5][0:2]]

# %%
l1[1:]
# Out:
# [[1, 2, 3, 4, 5]]

# %%
l1
# Out:
# ['string', [1, 2]]
