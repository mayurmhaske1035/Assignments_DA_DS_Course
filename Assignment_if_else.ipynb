# %%
age = 25

# %%
if age >= 18:
    print("eligible for vote")
else:
    print("Not eligible for vote")
# Out:
# eligible for vote

# %%
number = -7

# %%
if number > 0:
    print("positive")
elif number < 0:
    print("negative")
else:
    print("zero")
# Out:
# negative

# %%
marks = 70

# %%
if marks > 90:
    print("Grade A")
elif marks > 80:
    print("grade B")
elif marks > 70:
    print("Grade C")
else:
    print("Fail")
# Out:
# Fail

# %%
number  = 2

# %%
if number % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
year = 2005

# %%
if year % 4  == 0 and year % 100 != 0:
    print(" leap year ")
else:
    print(" not leap year")
# Out:
#  not leap year

# %%
a=10

# %%
b=20

# %%
c=30

# %%
if a> b:
    if a>c:
        print("A is greater")
elif b> a:
    if b> c:
        print("B is greater")
else :
    print("C is grater")

# %%
price = 98

# %%
if price >= 100:
    print(f'final price is ', price- price* 0.2 )
elif price >= 70:
    print(f' final price is ',price -price*.1 )
else:
    print(f' final price is ',price)
# Out:
#  final price is  88.2

# %% [markdown]
# #for loop

# %%
n= int(input(" enter N"))
# Out:
#  enter N 10

# %%
sum =0
for i in range(0,n):
    sum = sum + i
    print(sum)
# Out:
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45

# %%
n = 5

# %%
for i in range(1,11):
    print(n*i)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
l=[1,2,3,4,5]

# %%
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num = int(input("Enter the number:"))
if num <0:
    print("factorial is not define")
else:
    result = num * i
    print(result)
# Out:
# Enter the number: 5
# 25

# %%
for i in range(1,6):
    print('*'*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
str = input("enter string ")
for i in str:
    print(i)
# Out:
# enter string  hello
# h
# e
# l
# l
# o

# %%
l=[1,2,3,4,5,6,7,9]

# %%
sum_odd=0
sum_even= 0
for i in l:
    if i % 2 == 0:
        sum_even = sum_even + i
    else:
        sum_odd = sum_odd + i


print("sum of even  :",sum_even,"\n sum of odd :",sum_odd)
# Out:
# sum of even  : 12
#  sum of odd : 25
